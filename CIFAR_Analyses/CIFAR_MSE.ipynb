# %% [markdown]
# ## Feature importance for discriminator predictions for CIFAR-10
#
# This notebook can be used to replicate the results reported in  "Generative adversarial learning can explain why imagination seems less real as we grow up" by Ozsu, Petrova, Dekker & Dijkstra.
#
# Scripts would pass 5000 generated and 5000 real images through AlexNet and the discriminator from a given epoch. It uses layer-wise activations to predict discriminator predictions using Ridge regression and track the model performance through mean-squared error. The results of this analyses were reported in Figure 6, Panel A.
#
# To run this scripts, you would need to have the weights available which can be gathered from the OSF files. In this implementation, the weights are imported via Google Drive but other methods are also possible.
#
# For any questions or if you detect a bug: a.ozsu@ucl.ac.uk

# %%
# ============================================================================
# IMPORTS
# ============================================================================
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torchvision
import torchvision.transforms as transforms
from torchvision.utils import save_image

import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict, deque
import os
import pickle
import cv2
import warnings
from timeit import default_timer as timer

warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ============================================================================
# CONFIGURATION
# ============================================================================
class Config:
    """
    Central configuration for all hyperparameters.
    This class holds all the tunable parameters for the GAN, making it easy to
    see and modify the experimental setup from one place.
    """

    # --- 1. Dataset and Data Paths ---
    dataset_name = "cifar10"  # Options: 'cifar10', 'mnist'
    data_path = "./data"

    # --- 2. Model Architecture ---
    latent_dim = 128
    generator_feature_maps = 128
    critic_feature_maps = 128
    image_channels = 3

    # --- 3. WGAN-GP Training Parameters ---
    batch_size = 64
    num_epochs = 100
    learning_rate_generator = 0.0001
    learning_rate_critic = 0.0003
    adam_beta1 = 0.0
    adam_beta2 = 0.9
    critic_updates_per_generator_update = 1

    # --- 4. Stability and Regularization ---
    gradient_penalty_weight = 10


    # --- 5. Monitoring, Logging, and Saving ---
    monitor_every_steps = 50
    save_samples_every_steps = 200
    save_model_every_epochs = 5
    save_activations_every_epochs = 1  # Set to 1 to save activations every epoch

    # --- 6. File Paths ---
    local_path = "/content/GAN_Outputs_Final"
    output_dir = os.path.join(local_path, "outputs")
    checkpoint_dir = os.path.join(local_path, "checkpoints")
    activation_dir = os.path.join(local_path, "activations")

    def __init__(self):
        """Creates all necessary output directories to prevent FileNotFoundError."""
        if self.dataset_name == "mnist":
            self.image_channels = 1

        self.samples_dir = os.path.join(self.output_dir, "samples")
        self.monitoring_dir = os.path.join(self.output_dir, "monitoring")
        self.grad_cam_dir = os.path.join(self.output_dir, "grad_cam")

        os.makedirs(self.samples_dir, exist_ok=True)
        os.makedirs(self.monitoring_dir, exist_ok=True)
        os.makedirs(self.grad_cam_dir, exist_ok=True)
        os.makedirs(self.checkpoint_dir, exist_ok=True)
        os.makedirs(self.activation_dir, exist_ok=True)


config = Config()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
print(f"Outputs will be saved to: {config.local_path}")
# Out:
# Using device: cuda
# Outputs will be saved to: /content/GAN_Outputs_Final

# %%
# ============================================================================
# MODELS (GENERATOR & CRITIC)
# ============================================================================
class Generator(nn.Module):
    def __init__(self):
        super().__init__()
        self.activations = {}
        self.main = nn.Sequential(
            nn.ConvTranspose2d(
                config.latent_dim,
                config.generator_feature_maps * 8,
                4,
                1,
                0,
                bias=False,
            ),
            nn.BatchNorm2d(config.generator_feature_maps * 8),
            nn.ReLU(True),
            nn.ConvTranspose2d(
                config.generator_feature_maps * 8,
                config.generator_feature_maps * 4,
                4,
                2,
                1,
                bias=False,
            ),
            nn.BatchNorm2d(config.generator_feature_maps * 4),
            nn.ReLU(True),
            nn.ConvTranspose2d(
                config.generator_feature_maps * 4,
                config.generator_feature_maps * 2,
                4,
                2,
                1,
                bias=False,
            ),
            nn.BatchNorm2d(config.generator_feature_maps * 2),
            nn.ReLU(True),
            nn.ConvTranspose2d(
                config.generator_feature_maps * 2,
                config.generator_feature_maps,
                4,
                2,
                1,
                bias=False,
            ),
            nn.BatchNorm2d(config.generator_feature_maps),
            nn.ReLU(True),
            nn.ConvTranspose2d(
                config.generator_feature_maps,
                config.image_channels,
                3,
                1,
                1,
                bias=False,
            ),
            nn.Tanh(),
        )
        self._initialize_weights()
        self._register_hooks()

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d)):
                nn.init.orthogonal_(m.weight, gain=0.8)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1.0)
                nn.init.constant_(m.bias, 0.0)

    def _register_hooks(self):
        def get_hook(name):
            def hook(model, input, output):
                self.activations[name] = output.detach()


            return hook

        for i, layer in enumerate(self.main):
            if isinstance(layer, nn.ReLU) or isinstance(layer, nn.Tanh):
                layer.register_forward_hook(get_hook(f"gen_layer_{i}"))

    def forward(self, z):
        return self.main(z)

    def clear_activations(self):
        self.activations.clear()

class Critic(nn.Module):
    def __init__(self):
        super().__init__()
        self.activations = {}
        self.gradients = {}
        self.layer1 = nn.Sequential(
            nn.Conv2d(
                config.image_channels, config.critic_feature_maps, 4, 2, 1, bias=False
            ),
            nn.LeakyReLU(0.2, inplace=False),
        )
        self.layer2 = nn.Sequential(
            nn.Conv2d(
                config.critic_feature_maps,
                config.critic_feature_maps * 2,
                4,
                2,
                1,
                bias=False,
            ),
            nn.InstanceNorm2d(config.critic_feature_maps * 2, affine=True),
            nn.LeakyReLU(0.2, inplace=False),
        )
        self.layer3 = nn.Sequential(
            nn.Conv2d(
                config.critic_feature_maps * 2,
                config.critic_feature_maps * 4,
                4,
                2,
                1,
                bias=False,
            ),
            nn.InstanceNorm2d(config.critic_feature_maps * 4, affine=True),
            nn.LeakyReLU(0.2, inplace=False),
        )
        self.final_conv = nn.Conv2d(
            config.critic_feature_maps * 4, 1, 4, 1, 0, bias=False
        )
        self._initialize_weights()
        self._register_hooks()

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.orthogonal_(m.weight, gain=0.8)
            elif isinstance(m, nn.InstanceNorm2d):
                nn.init.constant_(m.weight, 1.0)
                nn.init.constant_(m.bias, 0.0)

    def _register_hooks(self):
        def get_activation_hook(name):
            def hook(model, input, output):
                self.activations[name] = output

            return hook

        def get_gradient_hook(name):
            def hook(model, grad_in, grad_out):
                self.gradients[name] = grad_out[0]

            return hook

        self.layer1[0].register_forward_hook(get_activation_hook("layer1"))
        self.layer1[0].register_full_backward_hook(get_gradient_hook("layer1"))
        self.layer2[0].register_forward_hook(get_activation_hook("layer2"))
        self.layer2[0].register_full_backward_hook(get_gradient_hook("layer2"))
        self.layer3[0].register_forward_hook(get_activation_hook("layer3"))
        self.layer3[0].register_full_backward_hook(get_gradient_hook("layer3"))

    def forward(self, x):
        h1 = self.layer1(x)
        h2 = self.layer2(h1)
        h3 = self.layer3(h2)
        out = self.final_conv(h3)
        return out.view(-1)

    def clear_hooks_data(self):
        self.activations.clear()
        self.gradients.clear()

# %%
# !unzip "/content/drive/MyDrive/checkpoints_newarch.zip" -d "/content"
# Out:
# Archive:  /content/drive/MyDrive/checkpoints_newarch.zip
#    creating: /content/checkpoints/
#   inflating: /content/checkpoints/C_epoch_1.pth
#   inflating: /content/checkpoints/C_epoch_10.pth
#   inflating: /content/checkpoints/C_epoch_100.pth
#   inflating: /content/checkpoints/C_epoch_11.pth
#   inflating: /content/checkpoints/C_epoch_12.pth
#   inflating: /content/checkpoints/C_epoch_13.pth
#   inflating: /content/checkpoints/C_epoch_14.pth
#   inflating: /content/checkpoints/C_epoch_15.pth
#   inflating: /content/checkpoints/C_epoch_16.pth
#   inflating: /content/checkpoints/C_epoch_17.pth
#   inflating: /content/checkpoints/C_epoch_18.pth
#   inflating: /content/checkpoints/C_epoch_19.pth
#   inflating: /content/checkpoints/C_epoch_2.pth
#   inflating: /content/checkpoints/C_epoch_20.pth
#   inflating: /content/checkpoints/C_epoch_21.pth
#   inflating: /content/checkpoints/C_epoch_22.pth
#   inflating: /content/checkpoints/C_epoch_23.pth
#   inflating: /content/checkpoints/C_epoch_24.pth
#   inflating: /content/checkpoints/C_epoch_25.pth
#   inflating: /content/checkpoints/C_epoch_26.pth
#   inflating: /content/checkpoints/C_epoch_27.pth
#   inflating: /content/checkpoints/C_epoch_28.pth
#   inflating: /content/checkpoints/C_epoch_29.pth
#   inflating: /content/checkpoints/C_epoch_3.pth
#   inflating: /content/checkpoints/C_epoch_30.pth
#   inflating: /content/checkpoints/C_epoch_31.pth
#   inflating: /content/checkpoints/C_epoch_32.pth
#   inflating: /content/checkpoints/C_epoch_33.pth
#   inflating: /content/checkpoints/C_epoch_34.pth
#   inflating: /content/checkpoints/C_epoch_35.pth
#   inflating: /content/checkpoints/C_epoch_36.pth
#   inflating: /content/checkpoints/C_epoch_37.pth
#   inflating: /content/checkpoints/C_epoch_38.pth
#   inflating: /content/checkpoints/C_epoch_39.pth
#   inflating: /content/checkpoints/C_epoch_4.pth
#   inflating: /content/checkpoints/C_epoch_40.pth
#   inflating: /content/checkpoints/C_epoch_41.pth
#   inflating: /content/checkpoints/C_epoch_42.pth
#   inflating: /content/checkpoints/C_epoch_43.pth
#   inflating: /content/checkpoints/C_epoch_44.pth
#   inflating: /content/checkpoints/C_epoch_45.pth
#   inflating: /content/checkpoints/C_epoch_46.pth
#   inflating: /content/checkpoints/C_epoch_47.pth
#   inflating: /content/checkpoints/C_epoch_48.pth
#   inflating: /content/checkpoints/C_epoch_49.pth
#   inflating: /content/checkpoints/C_epoch_5.pth
#   inflating: /content/checkpoints/C_epoch_50.pth
#   inflating: /content/checkpoints/C_epoch_51.pth
#   inflating: /content/checkpoints/C_epoch_52.pth
#   inflating: /content/checkpoints/C_epoch_53.pth
#   inflating: /content/checkpoints/C_epoch_54.pth
#   inflating: /content/checkpoints/C_epoch_55.pth
#   inflating: /content/checkpoints/C_epoch_56.pth
#   inflating: /content/checkpoints/C_epoch_57.pth
#   inflating: /content/checkpoints/C_epoch_58.pth
#   inflating: /content/checkpoints/C_epoch_59.pth
#   inflating: /content/checkpoints/C_epoch_6.pth
#   inflating: /content/checkpoints/C_epoch_60.pth
#   inflating: /content/checkpoints/C_epoch_61.pth
#   inflating: /content/checkpoints/C_epoch_62.pth
#   inflating: /content/checkpoints/C_epoch_63.pth
#   inflating: /content/checkpoints/C_epoch_64.pth
#   inflating: /content/checkpoints/C_epoch_65.pth
#   inflating: /content/checkpoints/C_epoch_66.pth
#   inflating: /content/checkpoints/C_epoch_67.pth
#   inflating: /content/checkpoints/C_epoch_68.pth
#   inflating: /content/checkpoints/C_epoch_69.pth
#   inflating: /content/checkpoints/C_epoch_7.pth
#   inflating: /content/checkpoints/C_epoch_70.pth
#   inflating: /content/checkpoints/C_epoch_71.pth
#   inflating: /content/checkpoints/C_epoch_72.pth
#   inflating: /content/checkpoints/C_epoch_73.pth
#   inflating: /content/checkpoints/C_epoch_74.pth
#   inflating: /content/checkpoints/C_epoch_75.pth
#   inflating: /content/checkpoints/C_epoch_76.pth
#   inflating: /content/checkpoints/C_epoch_77.pth
#   inflating: /content/checkpoints/C_epoch_78.pth
#   inflating: /content/checkpoints/C_epoch_79.pth
#   inflating: /content/checkpoints/C_epoch_8.pth
#   inflating: /content/checkpoints/C_epoch_80.pth
#   inflating: /content/checkpoints/C_epoch_81.pth
#   inflating: /content/checkpoints/C_epoch_82.pth
#   inflating: /content/checkpoints/C_epoch_83.pth
#   inflating: /content/checkpoints/C_epoch_84.pth
#   inflating: /content/checkpoints/C_epoch_85.pth
#   inflating: /content/checkpoints/C_epoch_86.pth
#   inflating: /content/checkpoints/C_epoch_87.pth
#   inflating: /content/checkpoints/C_epoch_88.pth
#   inflating: /content/checkpoints/C_epoch_89.pth
#   inflating: /content/checkpoints/C_epoch_9.pth
#   inflating: /content/checkpoints/C_epoch_90.pth
#   inflating: /content/checkpoints/C_epoch_91.pth
#   inflating: /content/checkpoints/C_epoch_92.pth
#   inflating: /content/checkpoints/C_epoch_93.pth
#   inflating: /content/checkpoints/C_epoch_94.pth
#   inflating: /content/checkpoints/C_epoch_95.pth
#   inflating: /content/checkpoints/C_epoch_96.pth
#   inflating: /content/checkpoints/C_epoch_97.pth
#   inflating: /content/checkpoints/C_epoch_98.pth
#   inflating: /content/checkpoints/C_epoch_99.pth
#   inflating: /content/checkpoints/G_epoch_1.pth
#   inflating: /content/checkpoints/G_epoch_10.pth
#   inflating: /content/checkpoints/G_epoch_100.pth
#   inflating: /content/checkpoints/G_epoch_11.pth
#   inflating: /content/checkpoints/G_epoch_12.pth
#   inflating: /content/checkpoints/G_epoch_13.pth
#   inflating: /content/checkpoints/G_epoch_14.pth
#   inflating: /content/checkpoints/G_epoch_15.pth
#   inflating: /content/checkpoints/G_epoch_16.pth
#   inflating: /content/checkpoints/G_epoch_17.pth
#   inflating: /content/checkpoints/G_epoch_18.pth
#   inflating: /content/checkpoints/G_epoch_19.pth
#   inflating: /content/checkpoints/G_epoch_2.pth
#   inflating: /content/checkpoints/G_epoch_20.pth
#   inflating: /content/checkpoints/G_epoch_21.pth
#   inflating: /content/checkpoints/G_epoch_22.pth
#   inflating: /content/checkpoints/G_epoch_23.pth
#   inflating: /content/checkpoints/G_epoch_24.pth
#   inflating: /content/checkpoints/G_epoch_25.pth
#   inflating: /content/checkpoints/G_epoch_26.pth
#   inflating: /content/checkpoints/G_epoch_27.pth
#   inflating: /content/checkpoints/G_epoch_28.pth
#   inflating: /content/checkpoints/G_epoch_29.pth
#   inflating: /content/checkpoints/G_epoch_3.pth
#   inflating: /content/checkpoints/G_epoch_30.pth
#   inflating: /content/checkpoints/G_epoch_31.pth
#   inflating: /content/checkpoints/G_epoch_32.pth
#   inflating: /content/checkpoints/G_epoch_33.pth
#   inflating: /content/checkpoints/G_epoch_34.pth
#   inflating: /content/checkpoints/G_epoch_35.pth
#   inflating: /content/checkpoints/G_epoch_36.pth
#   inflating: /content/checkpoints/G_epoch_37.pth
#   inflating: /content/checkpoints/G_epoch_38.pth
#   inflating: /content/checkpoints/G_epoch_39.pth
#   inflating: /content/checkpoints/G_epoch_4.pth
#   inflating: /content/checkpoints/G_epoch_40.pth
#   inflating: /content/checkpoints/G_epoch_41.pth
#   inflating: /content/checkpoints/G_epoch_42.pth
#   inflating: /content/checkpoints/G_epoch_43.pth
#   inflating: /content/checkpoints/G_epoch_44.pth
#   inflating: /content/checkpoints/G_epoch_45.pth
#   inflating: /content/checkpoints/G_epoch_46.pth
#   inflating: /content/checkpoints/G_epoch_47.pth
#   inflating: /content/checkpoints/G_epoch_48.pth
#   inflating: /content/checkpoints/G_epoch_49.pth
#   inflating: /content/checkpoints/G_epoch_5.pth
#   inflating: /content/checkpoints/G_epoch_50.pth
#   inflating: /content/checkpoints/G_epoch_51.pth
#   inflating: /content/checkpoints/G_epoch_52.pth
#   inflating: /content/checkpoints/G_epoch_53.pth
#   inflating: /content/checkpoints/G_epoch_54.pth
#   inflating: /content/checkpoints/G_epoch_55.pth
#   inflating: /content/checkpoints/G_epoch_56.pth
#   inflating: /content/checkpoints/G_epoch_57.pth
#   inflating: /content/checkpoints/G_epoch_58.pth
#   inflating: /content/checkpoints/G_epoch_59.pth
#   inflating: /content/checkpoints/G_epoch_6.pth
#   inflating: /content/checkpoints/G_epoch_60.pth
#   inflating: /content/checkpoints/G_epoch_61.pth
#   inflating: /content/checkpoints/G_epoch_62.pth
#   inflating: /content/checkpoints/G_epoch_63.pth
#   inflating: /content/checkpoints/G_epoch_64.pth
#   inflating: /content/checkpoints/G_epoch_65.pth
#   inflating: /content/checkpoints/G_epoch_66.pth
#   inflating: /content/checkpoints/G_epoch_67.pth
#   inflating: /content/checkpoints/G_epoch_68.pth
#   inflating: /content/checkpoints/G_epoch_69.pth
#   inflating: /content/checkpoints/G_epoch_7.pth
#   inflating: /content/checkpoints/G_epoch_70.pth
#   inflating: /content/checkpoints/G_epoch_71.pth
#   inflating: /content/checkpoints/G_epoch_72.pth
#   inflating: /content/checkpoints/G_epoch_73.pth
#   inflating: /content/checkpoints/G_epoch_74.pth
#   inflating: /content/checkpoints/G_epoch_75.pth
#   inflating: /content/checkpoints/G_epoch_76.pth
#   inflating: /content/checkpoints/G_epoch_77.pth
#   inflating: /content/checkpoints/G_epoch_78.pth
#   inflating: /content/checkpoints/G_epoch_79.pth
#   inflating: /content/checkpoints/G_epoch_8.pth
#   inflating: /content/checkpoints/G_epoch_80.pth
#   inflating: /content/checkpoints/G_epoch_81.pth
#   inflating: /content/checkpoints/G_epoch_82.pth
#   inflating: /content/checkpoints/G_epoch_83.pth
#   inflating: /content/checkpoints/G_epoch_84.pth
#   inflating: /content/checkpoints/G_epoch_85.pth
#   inflating: /content/checkpoints/G_epoch_86.pth
#   inflating: /content/checkpoints/G_epoch_87.pth
#   inflating: /content/checkpoints/G_epoch_88.pth
#   inflating: /content/checkpoints/G_epoch_89.pth
#   inflating: /content/checkpoints/G_epoch_9.pth
#   inflating: /content/checkpoints/G_epoch_90.pth
#   inflating: /content/checkpoints/G_epoch_91.pth
#   inflating: /content/checkpoints/G_epoch_92.pth
#   inflating: /content/checkpoints/G_epoch_93.pth
#   inflating: /content/checkpoints/G_epoch_94.pth
#   inflating: /content/checkpoints/G_epoch_95.pth
#   inflating: /content/checkpoints/G_epoch_96.pth
#   inflating: /content/checkpoints/G_epoch_97.pth
#   inflating: /content/checkpoints/G_epoch_98.pth
#   inflating: /content/checkpoints/G_epoch_99.pth

# %%
# ============================================================================
# DATASET LOADING
# ============================================================================
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import os

# ============================================================================
# DATASET LOADING
# ============================================================================
def get_dataloader():
    transform = transforms.Compose(
        [
            transforms.Resize(32),
            transforms.ToTensor(),
            transforms.Normalize(
                (0.5,) * config.image_channels, (0.5,) * config.image_channels
            ),
        ]
    )
    dataset_class = (
        torchvision.datasets.CIFAR10
        if config.dataset_name == "cifar10"
        else torchvision.datasets.MNIST
    )
    dataset = dataset_class(
        root=config.data_path, train=True, transform=transform, download=True
    )
    return DataLoader(
        dataset,
        batch_size=config.batch_size,
        shuffle=True,
        num_workers=2,
        pin_memory=True,
        drop_last=False,
    )



# ============================================================================
# IMPORTS
# ============================================================================
import torch
import torch.nn as nn
from torchvision import models
import torchvision
from tqdm import tqdm
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
from sklearn.linear_model import Ridge
import numpy as np
import pandas as pd
import torch.nn.functional as F
import gc
from google.colab import files


# ============================================================================
# SETTINGS
# ============================================================================
START_EPOCH = 1
END_EPOCH = 100

numImgs = 5000          # 5000 fake + 5000 real = 10000 total samples
batch_size = 128
out_dir = "./mse_results"
os.makedirs(out_dir, exist_ok=True)
checkpoint_dir = "/content/checkpoints"


# ============================================================================
# ALEXNET SETUP
# ============================================================================
alexnet = models.alexnet(pretrained=True).to(device).eval()

layer_names = ['conv1', 'conv2', 'conv3', 'conv4', 'conv5', 'fc1', 'fc2', 'fc3']
layers = {
    'conv1': alexnet.features[0],
    'conv2': alexnet.features[3],
    'conv3': alexnet.features[6],
    'conv4': alexnet.features[8],
    'conv5': alexnet.features[10],
    'fc1':   alexnet.classifier[1],
    'fc2':   alexnet.classifier[4],
    'fc3':   alexnet.classifier[6],
}

activations = {}

def get_activation(name):
    def hook(model, input, output):
        activations[name] = output.detach()
    return hook

for name, layer in layers.items():
    layer.register_forward_hook(get_activation(name))


# ============================================================================
# DATA + STATIC NOISE
# ============================================================================
real_loader = get_dataloader()
static_noise = torch.randn(numImgs, config.latent_dim, 1, 1, device=device)


# ============================================================================
# HELPERS
# ============================================================================
def stack_feature_batches(batch_list):
    if len(batch_list) == 0:
        return np.empty((0, 0))
    return np.concatenate(batch_list, axis=0)


def preprocess_for_alexnet(imgs):
    """
    Convert GAN/dataset images from [-1, 1] to AlexNet ImageNet format.
    """
    imgs = (imgs + 1) / 2
    imgs = imgs.clamp(0, 1)
    imgs = F.interpolate(imgs, size=(224, 224), mode='bilinear', align_corners=False)

    mean = torch.tensor([0.485, 0.456, 0.406], device=imgs.device).view(1, 3, 1, 1)
    std  = torch.tensor([0.229, 0.224, 0.225], device=imgs.device).view(1, 3, 1, 1)
    imgs = (imgs - mean) / std
    return imgs


def process_image_batch(imgs, C, alexnet, all_feats, scores_all, labels_all, label_name):
    """
    Process one batch of images through Critic + AlexNet.
    Stores:
      - critic score
      - AlexNet layer features
      - sample label ('fake' or 'real')
    """
    with torch.no_grad():
        # Critic scores
        s = C(imgs).detach().cpu().numpy()
        if s.ndim > 1:
            s = s.reshape(s.shape[0])
        scores_all.append(s)

        # Save labels
        labels_all.extend([label_name] * imgs.size(0))

        # AlexNet features
        alex_imgs = preprocess_for_alexnet(imgs)
        activations.clear()
        _ = alexnet(alex_imgs)

        for l in layer_names:
            f = activations[l]
            if f.dim() == 4:
                f = f.mean(dim=[2, 3])   # spatial average for conv layers
            all_feats[l].append(f.detach().cpu().numpy())


def generate_and_collect(G, C, noise_tensor, real_loader, numImgs=numImgs, batch_size=batch_size):
    """
    Collect:
      - numImgs fake images
      - numImgs real images

    Returns:
        all_feats: dict[layer] -> [2*numImgs, C]
        scores_all: [2*numImgs]
        labels_all: [2*numImgs] array of 'fake'/'real'
    """
    all_feats = {l: [] for l in layer_names}
    scores_all = []
    labels_all = []

    # ------------------ FAKE IMAGES ------------------
    fake_count = 0
    with torch.no_grad():
        for i in range(0, min(noise_tensor.shape[0], numImgs), batch_size):
            z = noise_tensor[i:i+batch_size].to(device)
            fake_imgs = G(z)

            process_image_batch(
                fake_imgs, C, alexnet,
                all_feats, scores_all, labels_all,
                label_name="fake"
            )

            fake_count += fake_imgs.size(0)
            if fake_count >= numImgs:
                break

    # ------------------ REAL IMAGES ------------------
    real_count = 0
    with torch.no_grad():
        for real_imgs, _ in real_loader:
            real_imgs = real_imgs.to(device)

            remaining = numImgs - real_count
            if remaining <= 0:
                break

            if real_imgs.size(0) > remaining:
                real_imgs = real_imgs[:remaining]

            process_image_batch(
                real_imgs, C, alexnet,
                all_feats, scores_all, labels_all,
                label_name="real"
            )

            real_count += real_imgs.size(0)
            if real_count >= numImgs:
                break

    # Stack into arrays
    for l in layer_names:
        all_feats[l] = stack_feature_batches(all_feats[l])

    scores_all = np.concatenate(scores_all, axis=0)
    labels_all = np.array(labels_all)

    print(f"Collected {np.sum(labels_all == 'fake')} fake images")
    print(f"Collected {np.sum(labels_all == 'real')} real images")
    print(f"Total samples: {len(labels_all)}")

    return all_feats, scores_all, labels_all


def ridge_cv_mse(X, y, alpha=1.0, n_splits=5):
    """
    Cross-validated MSE for Ridge regression.
    """
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    mses = []

    for train_idx, test_idx in kf.split(X):
        X_train, X_test = X[train_idx], X[test_idx]
        y_train, y_test = y[train_idx], y[test_idx]

        y_train_mean = y_train.mean()
        y_train_std = y_train.std()

        # avoid divide-by-zero
        if y_train_std < 1e-12:
            y_train_std = 1.0

        y_train_z = (y_train - y_train_mean) / y_train_std
        y_test_z  = (y_test  - y_train_mean) / y_train_std

        model = Ridge(alpha=alpha, fit_intercept=True)
        model.fit(X_train, y_train_z)

        y_pred_z = model.predict(X_test)
        mse = mean_squared_error(y_test_z, y_pred_z)
        mses.append(mse)

    return {
        "cv_mse_mean": float(np.mean(mses)),
        "cv_mse_std": float(np.std(mses)),
        "alpha": alpha,
    }



# ============================================================================
# MAIN LOOP
# ============================================================================
all_results = []

for epoch in range(START_EPOCH, END_EPOCH + 1):
    print("\n==============================")
    print(f"Epoch {epoch}: Loading Generator and Critic")
    print("==============================")

    # --- Load Generator ---
    try:
        G_eval = Generator().to(device)
        g_path = os.path.join(checkpoint_dir, f"G_epoch_{epoch}.pth")
        G_eval.load_state_dict(torch.load(g_path, map_location=device))
        G_eval.eval()
    except FileNotFoundError:
        print(f"WARNING: Generator checkpoint for epoch {epoch} not found. Skipping.")
        continue

    # --- Load Critic ---
    try:
        C_eval = Critic().to(device)
        c_path = os.path.join(checkpoint_dir, f"C_epoch_{epoch}.pth")
        C_eval.load_state_dict(torch.load(c_path, map_location=device))
        C_eval.eval()
    except FileNotFoundError:
        print(f"WARNING: Critic checkpoint for epoch {epoch} not found. Skipping.")
        continue

    # --- Collect 5k fake + 5k real ---
    noise_to_use = static_noise[:numImgs]

    all_feats, scores, labels = generate_and_collect(
        G_eval,
        C_eval,
        noise_to_use,
        real_loader=real_loader,
        numImgs=numImgs,
        batch_size=batch_size
    )

    # --- Ridge MSE for each AlexNet layer on combined real+fake ---
    for l in layer_names:
        X = all_feats[l]
        y = scores.copy()

        res = ridge_cv_mse(X, y, alpha=1.0, n_splits=5)
        res.update({
            "layer": l,
            "epoch": epoch,
        })
        all_results.append(res)


    gc.collect()
    torch.cuda.empty_cache()


# ============================================================================
# SAVE RESULTS
# ============================================================================
df_mse = pd.DataFrame(all_results)
csv_path = os.path.join(out_dir, "MSE_CV_over_epochs_CIFAR.csv")
df_mse.to_csv(csv_path, index=False)

print("✅ Saved accumulated MSE results to:", csv_path)
files.download(csv_path)
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100%|██████████| 233M/233M [00:01<00:00, 128MB/s]
# 100%|██████████| 170M/170M [00:13<00:00, 13.1MB/s]
# ==============================
# Epoch 1: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 2: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 3: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 4: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 5: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 6: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 7: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 8: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 9: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 10: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 11: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 12: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 13: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 14: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 15: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 16: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 17: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 18: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 19: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 20: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 21: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 22: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 23: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 24: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 25: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 26: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 27: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 28: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 29: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 30: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 31: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 32: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 33: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 34: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 35: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 36: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 37: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 38: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 39: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 40: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 41: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 42: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 43: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 44: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 45: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 46: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 47: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 48: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 49: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 50: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 51: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 52: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 53: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 54: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 55: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 56: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 57: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 58: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 59: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 60: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 61: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 62: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 63: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 64: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 65: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 66: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 67: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 68: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 69: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 70: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 71: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 72: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 73: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 74: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 75: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 76: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 77: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 78: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 79: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 80: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 81: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 82: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 83: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 84: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 85: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 86: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 87: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 88: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 89: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 90: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 91: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 92: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 93: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 94: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 95: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 96: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 97: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 98: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 99: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
#
# ==============================
# Epoch 100: Loading Generator and Critic
# ==============================
# Collected 5000 fake images
# Collected 5000 real images
# Total samples: 10000
# ✅ Saved accumulated MSE results to: ./mse_results/MSE_CV_over_epochs_CIFAR.csv
